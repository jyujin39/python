# %% [markdown]
# # Bike Sharing Demand Prediction

# %% [markdown]
# You are provided hourly rental data spanning two years. For this competition, the training set is comprised of the first 19 days of each month, while the test set is the 20th to the end of the month. You must predict the total count of bikes rented during each hour covered by the test set, using only information available prior to the rental period.

# %% [markdown]
# - datetime - hourly date + timestamp
# - season -  1 = spring, 2 = summer, 3 = fall, 4 = winter
# - holiday - whether the day is considered a holiday
# - workingday - whether the day is neither a weekend nor holiday
# - weather
#     - 1: Clear, Few clouds, Partly cloudy, Partly cloudy
#     - 2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
#     - 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
#     - 4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
# - temp - temperature in Celsius
# - atemp - "feels like" temperature in Celsius
# - humidity - relative humidity
# - windspeed - wind speed
# - casual - number of non-registered user rentals initiated
# - registered - number of registered user rentals initiated
# - count - number of total rentals

# %% [markdown]
# ## EDA 및 전처리

# %%
train = pd.read_csv('train.csv')

# %%
train.tail()
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# 10881  19.695        50    26.0027       7         329    336
# 10882  17.425        57    15.0013      10         231    241
# 10883  15.910        61    15.0013       4         164    168
# 10884  17.425        61     6.0032      12         117    129
# 10885  16.665        66     8.9981       4          84     88

# %%
test = pd.read_csv("test.csv")
test.tail()
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 6488  2012-12-31 19:00:00       1        0           1        2  10.66
# 6489  2012-12-31 20:00:00       1        0           1        2  10.66
# 6490  2012-12-31 21:00:00       1        0           1        1  10.66
# 6491  2012-12-31 22:00:00       1        0           1        1  10.66
# 6492  2012-12-31 23:00:00       1        0           1        1  10.66
#
#        atemp  humidity  windspeed
# 6488  12.880        60    11.0014
# 6489  12.880        60    11.0014
# 6490  12.880        60    11.0014
# 6491  13.635        56     8.9981
# 6492  13.635        65     8.9981

# %% [markdown]
# - train 데이터 10885개
# - test 데이터 6492개

# %% [markdown]
# #### 범주형/연속형 데이터 구분

# %% [markdown]
# - 범주형: season, holiday, workingday, weather
# - 연속형: datetime, temp, atemp, humidity, windspeed

# %%
set(train.season)
# Out:
# {1, 2, 3, 4}

# %%
set(train.holiday)
# Out:
# {0, 1}

# %%
set(train.workingday)
# Out:
# {0, 1}

# %%
set(train.weather)
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# #### Datetime 변수 전처리

# %%
train.datetime = pd.to_datetime(train.datetime)

# %%
train['year'] = train.datetime.apply(lambda x : x.year)

# %%
train['month'] = train.datetime.apply(lambda x : x.month)

# %%
train['hour'] = train.datetime.apply(lambda x : x.hour)

# %%
train['day'] = train.datetime.apply(lambda x : x.day)

# %%
train['y_m_d'] = train.datetime.apply(lambda x : x.date())

# %%
train['day_of_week'] = train.datetime.apply(lambda x : x.weekday())

# %%
train = train.drop(columns='datetime')

# %%
train.tail()
# Out:
#        season  holiday  workingday  weather   temp   atemp  humidity  \
# 10881       4        0           1        1  15.58  19.695        50
# 10882       4        0           1        1  14.76  17.425        57
# 10883       4        0           1        1  13.94  15.910        61
# 10884       4        0           1        1  13.94  17.425        61
# 10885       4        0           1        1  13.12  16.665        66
#
#        windspeed  casual  registered  count  year  month  hour  day  \
# 10881    26.0027       7         329    336  2012     12    19   19
# 10882    15.0013      10         231    241  2012     12    20   19
# 10883    15.0013       4         164    168  2012     12    21   19
# 10884     6.0032      12         117    129  2012     12    22   19
# 10885     8.9981       4          84     88  2012     12    23   19
#
#             y_m_d  day_of_week
# 10881  2012-12-19            2
# 10882  2012-12-19            2
# 10883  2012-12-19            2
# 10884  2012-12-19            2
# 10885  2012-12-19            2

# %% [markdown]
# #### 요일에 따른 자전거 대여 방식별 대여횟수

# %%
pivot = train[['day_of_week','casual','registered','count']].pivot_table(index='day_of_week',
                                                                 values=['casual','registered','count'], aggfunc=sum)
pivot
# Out:
#              casual   count  registered
# day_of_week
# 0             46288  295296      249008
# 1             35365  291985      256620
# 2             34931  292226      257295
# 3             37283  306401      269118
# 4             47402  302504      255102
# 5            100782  311518      210736
# 6             90084  285546      195462

# %%
plot = plt.subplot(111)
plot.bar(pivot.index.values-0.2, pivot.values[:,0], width=0.2, color='b', align='center') #casual
plot.bar(pivot.index.values, pivot.values[:,2], width=0.2, color='g', align='center') #registered
plot.bar(pivot.index.values+0.2, pivot.values[:,1], width=0.2, color='r', align='center') #count
plt.show()

# %% [markdown]
# > registered로 자전거를 대여하는 빈도수는 평일에 더 많고,
# casual로 자전거를 대여하는 빈도수는 주말에 더 많음을 알 수 있다.
#
# >모두 합친 count는 요일에 관계 없이 대체적으로 비슷한 분포를 보인다.

# %% [markdown]
# #### 일, 월, 시간별 자전거 대여횟수의 평균

# %%
day_count = train[['day','count']].groupby(by='day').agg(np.mean)
day_count.tail()
# Out:
#           count
# day
# 15   201.527875
# 16   191.353659
# 17   205.660870
# 18   192.605684
# 19   192.311847

# %%
sns.barplot(x=train['day'].value_counts().index, y=day_count.values.flatten())
plt.show()

# %%
month_count = train[['month','count']].groupby(by='month').agg(np.mean)
month_count.tail()
# Out:
#             count
# month
# 8      234.118421
# 9      233.805281
# 10     227.699232
# 11     193.677278
# 12     175.614035

# %%
sns.barplot(x=train['month'].value_counts().index, y=month_count.values.flatten())
plt.show()

# %%
hour_count = train[['hour','count']].groupby(by='hour').agg(np.mean)
hour_count.tail()
# Out:
#            count
# hour
# 19    315.278509
# 20    228.517544
# 21    173.370614
# 22    133.576754
# 23     89.508772

# %%
sns.barplot(x=train['hour'].value_counts().index, y=hour_count.values.flatten())
plt.show()

# %% [markdown]
# > 날짜는 자전거 대여횟수에 큰 영향을 미치지 않고, 월과 시간이 자전거대여횟수와 상관관계가 있음을 알 수 있다.

# %% [markdown]
# #### 결측데이터 처리
#
# 이 데이터셋에서 missing value는 humidity와 windspeed에만 존재하는데, nan 값이 아닌 숫자 0으로 된 값들이다.
#
# - humidity 22개
# - windspeed 1313개

# %%
len(train[train.humidity==0])
# Out:
# 22

# %%
len(train[train.windspeed==0])
# Out:
# 1313

# %%
sns.distplot(train.windspeed)
plt.show()

# %%
sns.distplot(train.humidity)
plt.show()

# %% [markdown]
# 우선 windspeed의 결측치는 결측치가 존재하는 날짜의 바람세기 평균값으로 대체하기로 한다.

# %%
windspeed_mean = train[['windspeed','y_m_d']].groupby(by='y_m_d').agg('mean')
windspeed_mean = windspeed_mean.rename(columns={'windspeed':'windspeed_mean'})

# %%
train = pd.merge(train, windspeed_mean, on='y_m_d')

# %%
new = train.windspeed.values

# %%
for i in range(len(new)):
    if new[i] == 0:
        new[i] = train.windspeed_mean.values[i]

# %%
train.windspeed = new

# %%
train = train.drop(columns='windspeed_mean')

# %%
train.head()
# Out:
#    season  holiday  workingday  weather  temp   atemp  humidity  windspeed  \
# 0       1        0           0        1  9.84  14.395        81  10.749871
# 1       1        0           0        1  9.02  13.635        80  10.749871
# 2       1        0           0        1  9.02  13.635        80  10.749871
# 3       1        0           0        1  9.84  14.395        75  10.749871
# 4       1        0           0        1  9.84  14.395        75  10.749871
#
#    casual  registered  count  year  month  hour  day       y_m_d  day_of_week
# 0       3          13     16  2011      1     0    1  2011-01-01            5
# 1       8          32     40  2011      1     1    1  2011-01-01            5
# 2       5          27     32  2011      1     2    1  2011-01-01            5
# 3       3          10     13  2011      1     3    1  2011-01-01            5
# 4       0           1      1  2011      1     4    1  2011-01-01            5

# %%
sns.distplot(train.windspeed)
plt.show()

# %% [markdown]
# humidity는 결측값 22개가 모두 2011년 3월 10일 하루에 해당하는 결측값임을 알 수 있다.

# %%
train[train.humidity==0]
# Out:
#       season  holiday  workingday  weather   temp   atemp  humidity  \
# 1091       1        0           1        3  13.94  15.910         0
# 1092       1        0           1        3  13.94  15.910         0
# 1093       1        0           1        3  13.94  15.910         0
# 1094       1        0           1        3  14.76  17.425         0
# 1095       1        0           1        3  14.76  16.665         0
# 1096       1        0           1        3  15.58  19.695         0
# 1097       1        0           1        3  15.58  19.695         0
# 1098       1        0           1        3  16.40  20.455         0
# 1099       1        0           1        3  16.40  20.455         0
# 1100       1        0           1        3  16.40  20.455         0
# 1101       1        0           1        3  17.22  21.210         0
+05
# Df Model:                          13
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# season        -10.9369      5.381     -2.033      0.042     -21.484      -0.390
# holiday         1.7416     10.438      0.167      0.867     -18.719      22.202
# workingday      3.0775      5.142      0.598      0.550      -7.002      13.157
# weather         0.8352      2.516      0.332      0.740      -4.097       5.768
# temp            2.2591      1.077      2.098      0.036       0.149       4.370
# atemp           4.3812      0.991      4.420      0.000       2.438       6.324
# humidity       -2.4678      0.094    -26.386      0.000      -2.651      -2.284
# windspeed       0.0185      0.220      0.084      0.933      -0.413       0.450
# year            0.0273      0.006      4.529      0.000       0.016       0.039
# month          10.8948      1.749      6.228      0.000       7.466      14.324
# hour            7.4861      0.216     34.636      0.000       7.062       7.910
# day             0.4052      0.258      1.572      0.116      -0.100       0.910
# day_of_week     0.8523      1.181      0.722      0.470      -1.463       3.167
# ==============================================================================
# Omnibus:                     2630.220   Durbin-Watson:                   0.518
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5923.508
# Skew:                           1.377   Prob(JB):                         0.00
# Kurtosis:                       5.339   Cond. No.                     1.56e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.56e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
sns.distplot(train['count'])
plt.show()

# %% [markdown]
# 종속변수가 한쪽으로 강하게 치우쳐 있으므로 로그변환해준다.

# %%
sns.distplot(np.log1p(train['count']))
plt.show()

# %% [markdown]
# 종속변수에 로그를 취해주고 독립변수에는 정규화 혹은 범주형변수 인코딩을 해주고 나서 돌린 모델은 다음과 같다.

# %%
model1 = sm.OLS.from_formula('np.log1p(count) ~ C(season) + C(holiday) + C(workingday) + C(weather) + scale(temp) +\
scale(atemp) + scale(humidity) + scale(windspeed) + C(year) + C(month) + C(hour) + C(day) + C(day_of_week) + 0', train)
result1 = model1.fit()
print(result1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        np.log1p(count)   R-squared:                       0.835
# Model:                            OLS   Adj. R-squared:                  0.834
# Method:                 Least Squares   F-statistic:                     818.4
# Date:                Wed, 12 Dec 2018   Prob (F-statistic):               0.00
# Time:                        17:13:18   Log-Likelihood:                -9444.7
# No. Observations:               10886   AIC:                         1.903e+04
# Df Residuals:                   10818   BIC:                         1.952e+04
# Df Model:                          67
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# C(season)[1]            1.4823      0.032     46.175      0.000       1.419       1.545
# C(season)[2]            1.5562      0.018     86.904      0.000       1.521       1.591
# C(season)[3]            1.5529      0.021     74.222      0.000       1.512       1.594
# C(season)[4]            1.6514      0.018     90.471      0.000       1.616       1.687
# C(holiday)[T.1]         1.5306      0.034     45.217      0.000       1.464       1.597
# C(workingday)[T.1]      1.4958      0.022     67.980      0.000       1.453       1.539
# C(weather)[T.2]        -0.0468      0.014     -3.378      0.001      -0.074      -0.020
# C(weather)[T.3]        -0.5010      0.024    -21.165      0.000      -0.547      -0.455
# C(weather)[T.4]        -0.0898      0.580     -0.155      0.877      -1.227       1.047
# C(year)[T.2012]         0.4790      0.011     42.356      0.000       0.457       0.501
# C(month)[T.2]           0.1632      0.028      5.871      0.000       0.109       0.218
# C(month)[T.3]           0.2594      0.030      8.774      0.000       0.201       0.317
# C(month)[T.4]           0.3852      0.018     21.453      0.000       0.350       0.420
# C(month)[T.5]           0.6131      0.017     35.883      0.000       0.580       0.647
# C(month)[T.6]           0.5579      0.019     29.532      0.000       0.521       0.595
# C(month)[T.7]           0.4652      0.018     25.526      0.000       0.429       0.501
# C(month)[T.8]           0.5013      0.018     28.087      0.000       0.466       0.536
# C(month)[T.9]           0.5864      0.017     34.428      0.000       0.553       0.620
# C(day)[T.17]            0.1219      0.034      3.546      0.000       0.055       0.189
# C(day)[T.18]            0.0474      0.034      1.380      0.168      -0.020       0.115
# C(day)[T.19]            0.0545      0.034      1.596      0.111      -0.012       0.122
# C(day_of_week)[T.1]    -0.0056      0.022     -0.257      0.798      -0.048       0.037
# C(day_of_week)[T.2]     0.0060      0.021      0.279      0.780      -0.036       0.048
# C(day_of_week)[T.3]     0.0672      0.022      3.110      0.002       0.025       0.110
# C(day_of_week)[T.4]     0.1595      0.022      7.413      0.000       0.117       0.202
# C(day_of_week)[T.5]     1.6613      0.021     77.389      0.000       1.619       1.703
# C(day_of_week)[T.6]     1.5551      0.021     72.458      0.000       1.513       1.597
# scale(temp)             0.0440      0.038      1.158      0.247      -0.030       0.119
# scale(atemp)            0.1682      0.035      4.875      0.000       0.101       0.236
# scale(humidity)        -0.0717      0.008     -8.978      0.000      -0.087      -0.056
# scale(windspeed)       -0.0366      0.006     -5.858      0.000      -0.049      -0.024
# ==============================================================================
# Omnibus:                      746.453   Durbin-Watson:                   0.549
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1460.844
# Skew:                          -0.483   Prob(JB):                         0.00
# Kurtosis:                       4.513   Cond. No.                     3.65e+15
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.8e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# > 조건수가 높은 것으로 보아 독립변수들 사이에 상관관계가 존재할 것이 의심되므로 다중공선성 검사를 진행한다.

# %% [markdown]
# #### 다중공선성 검사

# %%
train_vif = train.drop(columns=['count', 'casual', 'registered', 'y_m_d'])

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(
    train_vif.values, i) for i in range(train_vif.shape[1])]
vif["features"] = train_vif.columns
vif = vif.sort_values(by=["VIF Factor"], ascending=False).reset_index(drop=True)
vif
# Out:
#     VIF Factor     features
# 0   311.885544        atemp
# 1   273.965579         temp
# 2   109.600108       season
# 3    83.688129        month
# 4    74.157827         year
# 5    18.501338     humidity
# 6     9.188382  day_of_week
# 7     9.052215   workingday
# 8     7.685199      weather
# 9     5.865255    windspeed
# 10    4.337700          day
# 11    4.252417         hour
# 12    1.565157      holiday

# %% [markdown]
# 다중공선성이 가장 높은 두 변수 atemp와 Temp, 즉 기온과 체감온도는 0.98의 상관계수로 매우 높은 상관관계를 보인다.
#
# 따라서 둘 중 하나의 변수는 버려야 한다.
#
# temp 와 atemp 중 어떤 것이 모델에 더 영향을 주는지 확인해본다.

# %%
np.corrcoef(train.temp, train.atemp)
# Out:
# array([[1.        , 0.98494811],
#        [0.98494811, 1.        ]])

# %%
model_partial = sm.OLS.from_formula('count ~ temp + atemp + 0', train)
result_partial = model_partial.fit()

# %%
fig = plt.figure(figsize=(5, 8))
sm.graphics.plot_partregress_grid(result_partial, fig=fig)
fig.suptitle("")
plt.show()

# %%
print(result_partial.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  count   R-squared:                       0.601
# Model:                            OLS   Adj. R-squared:                  0.601
# Method:                 Least Squares   F-statistic:                     8212.
# Date:                Wed, 12 Dec 2018   Prob (F-statistic):               0.00
# Time:                        17:04:29   Log-Likelihood:                -71125.
# No. Observations:               10886   AIC:                         1.423e+05
# Df Residuals:                   10884   BIC:                         1.423e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# temp           7.9074      1.135      6.965      0.000       5.682      10.133
# atemp          1.3171      0.980      1.345      0.179      -0.603       3.237
# ==============================================================================
# Omnibus:                     1850.806   Durbin-Watson:                   0.369
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3170.515
# Skew:                           1.114   Prob(JB):                         0.00
# Kurtosis:                       4.422   Cond. No.                         31.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# > atemp를 버리고 다시 다중공선성 체크를 해본다.

# %%
train_vif = train_vif.drop(columns='atemp')

# %%
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(
    train_vif.values, i) for i in range(train_vif.shape[1])]
vif["features"] = train_vif.columns
vif = vif.sort_values(by=["VIF Factor"], ascending=False).reset_index(drop=True)
vif
# Out:
#     VIF Factor     features
# 0   109.600102       season
# 1    83.686455        month
# 2    70.125617         year
# 3    18.427083     humidity
# 4     9.124789  day_of_week
# 5     8.986697   workingday
# 6     8.595359         temp
# 7     7.673746      weather
# 8     5.696462    windspeed
# 9     4.336546          day
# 10    4.248693         hour
# 11    1.555930      holiday

# %% [markdown]
# 이제는 season과 month의 강한 상관관계가 예상되는 상황이다. 두 범주형 데이터를 하나씩 모델에서 빼보고 더 성능이 좋아지는 변수를 선택한다.
#
# 결정계수 값이 season을 넣었을 때는 0.832, month를 넣었을 때는 0.835이므로 season 변수를 제거한다.

# %%
model2 = sm.OLS.from_formula('np.log1p(count) ~ C(holiday) + C(workingday) + C(weather) +\
scale(temp) + scale(humidity) + scale(windspeed) + C(year) + C(month) + C(hour) + C(day) + C(day_of_week) + 0', train)
result2 = model2.fit()
print(result2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        np.log1p(count)   R-squared:                       0.835
# Model:                            OLS   Adj. R-squared:                  0.834
# Method:                 Least Squares   F-statistic:                     828.7
# Date:                Wed, 12 Dec 2018   Prob (F-statistic):               0.00
# Time:                        17:14:50   Log-Likelihood:                -9456.7
# No. Observations:               10886   AIC:                         1.905e+04
# Df Residuals:                   10819   BIC:                         1.954e+04
# Df Model:                          66
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# C(holiday)[0]           2.2970      0.035     65.997      0.000       2.229       2.365
# C(holiday)[1]           3.0167      0.056     53.985      0.000       2.907       3.126
# C(workingday)[T.1]      0.6914      0.017     39.984      0.000       0.657       0.725
# C(weather)[T.2]        -0.0486      0.014     -3.509      0.000      -0.076      -0.021
# C(weather)[T.3]        -0.5080      0.024    -21.480      0.000      -0.554      -0.462
# C(weather)[T.4]        -0.0801      0.581     -0.138      0.890      -1.218       1.058
# C(year)[T.2012]         0.4775      0.011     42.198      0.000       0.455       0.500
# C(month)[T.2]           0.1682      0.028      6.050      0.000       0.114       0.223
# C(month)[T.3]           0.2624      0.030      8.870      0.000       0.204       0.320
# C(month)[T.4]           0.4655      0.031     14.816      0.000       0.404       0.527
# C(month)[T.5]           0.6869      0.036     19.185      0.000       0.617       0.757
# C(month)[T.6]           0.6213      0.041     15.238      0.000       0.541       0.701
# C(month)[T.7]           0.5179      0.046     11.338      0.000       0.428       0.607
# C(month)[T.8]           0.5437      0.044     12.255      0.000       0.457       0.631
# C(month)[T.9]           0.6457      0.039     16.348      0.000       0.568       0.723
# C(month)[T.10]          0.7652      0.034     22.513      0.000       0.699       0.832
# C(month)[T.11]          0.7225      0.029     24.866      0.000       0.666       0.779
# C(month)[T.12]          0.6810      0.029     23.568      0.000       0.624       0.738
# C(hour)[T.1]           -0.6071      0.038    -15.814      0.000      -0.682      -0.532
# C(hour)[T.2]           -1.1003      0.039    -28.551      0.000      -1.176      -1.025
# C(hour)[T.3]           -1.5940      0.039    -40.966      0.000      -1.670      -1.518
# C(hour)[T.4]           -1.8597      0.039    -47.994      0.000      -1.936      -1.784
# C(hour)[T.5]           -0.9019      0.039    -23.394      0.000      -0.978      -0.826
# C(hour)[T.6]            0.2790      0.039      7.247      0.000       0.204       0.355
# C(hour)[T.7]            1.2475      0.038     32.449      0.000       1.172       1.323
548
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1449.117
# Skew:                          -0.485   Prob(JB):                         0.00
# Kurtosis:                       4.501   Cond. No.                     1.08e+15
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.99e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
train_vif = train_vif.drop(columns='season')

# %%
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(
    train_vif.values, i) for i in range(train_vif.shape[1])]
vif["features"] = train_vif.columns
vif = vif.sort_values(by=["VIF Factor"], ascending=False).reset_index(drop=True)
vif
# Out:
#     VIF Factor     features
# 0    66.455631         year
# 1    18.381747     humidity
# 2     9.123513  day_of_week
# 3     8.986512   workingday
# 4     8.586329         temp
# 5     7.672263      weather
# 6     5.693013    windspeed
# 7     5.253372        month
# 8     4.336545          day
# 9     4.247442         hour
# 10    1.542881      holiday

# %% [markdown]
# atemp와 season 변수를 제거한 후 다중공선성을 확인해보면 year의 vif factor가 상대적으로 높다고 판단되어 모델에서 빼보았지만 결정계수가 0.835에서 0.805로 현저히 낮아지므로 일단 모형에 포함시키기로 한다.

# %% [markdown]
# 또한 hour이 cycle을 가진 변수라고 생각되어 아래와 같이 주기성을 넣어 모델에 적용해보았으나 오히려 성능이 떨어져서 그냥 범주형 변수로 고려하기로 한다.

# %%
model3 = sm.OLS.from_formula('np.log1p(count) ~ C(holiday) + C(workingday) + C(weather) + scale(temp)\
+ scale(humidity) + scale(windspeed) + C(year) + C(month) + C(day) + C(day_of_week)\
+ scale(np.sin(I(2*np.pi*(hour/24)))) * scale(np.cos(I(2*np.pi*(hour/24))))\
+ 0', train)
result3 = model3.fit()
print(result3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        np.log1p(count)   R-squared:                       0.765
# Model:                            OLS   Adj. R-squared:                  0.764
# Method:                 Least Squares   F-statistic:                     767.9
# Date:                Wed, 12 Dec 2018   Prob (F-statistic):               0.00
# Time:                        17:19:34   Log-Likelihood:                -11372.
# No. Observations:               10886   AIC:                         2.284e+04
# Df Residuals:                   10839   BIC:                         2.318e+04
# Df Model:                          46
# Covariance Type:            nonrobust
# =======================================================================================================================================================
#                                                                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# C(holiday)[0]                                                                           2.8796      0.033     86.835      0.000       2.815       2.945
# C(holiday)[1]                                                                           3.7977      0.058     65.734      0.000       3.684       3.911
# C(workingday)[T.1]                                                                      0.8884      0.019     47.059      0.000       0.851       0.925
# C(weather)[T.2]                                                                        -0.0674      0.016     -4.086      0.000      -0.100      -0.035
# C(weather)[T.3]                                                                        -0.4919      0.028    -17.469      0.000      -0.547      -0.437
# C(weather)[T.4]                                                                         0.1718      0.691      0.249      0.804      -1.183       1.526
# C(year)[T.2012]                                                                         0.4832      0.013     35.854      0.000       0.457       0.510
# C(month)[T.2]                                                                           0.1757      0.033      5.304      0.000       0.111       0.241
# C(month)[T.3]                                                                           0.2845      0.035      8.075      0.000       0.215       0.354
# C(month)[T.4]                                                                           0.4989      0.037     13.340      0.000       0.426       0.572
# C(month)[T.5]                                                                           0.7273      0.043     17.068      0.000       0.644       0.811
# C(month)[T.6]                                                                           0.6870      0.049     14.164      0.000       0.592       0.782
# C(month)[T.7]                                                                           0.5999      0.054     11.046      0.000       0.493       0.706
# C(month)[T.8]                                                                           0.6172      0.053     11.698      0.000       0.514       0.721
# C(month)[T.9]                                                                           0.6967      0.047     14.823      0.000       0.605       0.789
# C(month)[T.10]                                                                          0.7968      0.040     19.692      0.000       0.717       0.876
# C(month)[T.11]                                                                          0.7369      0.035     21.295      0.000       0.669       0.805
# C(month)[T.12]                                                                          0.6853      0.034     19.911      0.000       0.618       0.753
# C(day)[T.2]                                                                             0.0048      0.041      0.118      0.906      -0.075       0.085
# C(day)[T.3]                                                                             0.0151      0.041      0.370      0.711      -0.065       0.095
# C(day)[T.4]                                                                             0.0308      0.041      0.751      0.453      -0.050       0.111
# C(day)[T.5]                                                                             0.0282      0.041      0.692      0.489      -0.052       0.108
# C(day)[T.6]                                                                             0.0111      0.041      0.272      0.786      -0.069       0.091
# C(day)[T.7]                                                                            -0.0321      0.041     -0.787      0.431      -0.112       0.048
# C(day)[T.8]                                                                            -0.0176      0.041     -0.431      0.666      -0.098       0.062
# C(day)[T.9]                                                                             0.0321      0.041      0.787      0.432      -0.048       0.112
# C(day)[T.10]                                                                            0.0120      0.041      0.293      0.770      -0.068       0.092
# C(day)[T.11]                                                                            0.0558      0.041      1.361      0.174      -0.025       0.136
# C(day)[T.12]                                                                            0.0007      0.041      0.018      0.986      -0.079       0.081
# C(day)[T.13]                                                                            0.0390      0.041      0.954      0.340      -0.041       0.119
# C(day)[T.14]                                                                            0.0382      0.041      0.935      0.350      -0.042       0.118
# C(day)[T.15]                                                                            0.0879      0.041      2.153      0.031       0.008       0.168
# C(day)[T.16]                                                                            0.0328      0.041      0.801      0.423      -0.047       0.113
# C(day)[T.17]                                                                            0.1056      0.041      2.589      0.010       0.026       0.186
# C(day)[T.18]                                                                            0.0489      0.041      1.193      0.233      -0.031       0.129
# C(day)[T.19]                                                                            0.0575      0.041      1.411      0.158      -0.022       0.137
# C(day_of_week)[T.1]                                                                    -0.0080      0.026     -0.309      0.757      -0.059       0.043
# C(day_of_week)[T.2]                                                                    -0.0001      0.026     -0.005      0.996      -0.050       0.050
# C(day_of_week)[T.3]                                                                     0.0650      0.026      2.522      0.012       0.014       0.115
# C(day_of_week)[T.4]                                                                     0.1504      0.026      5.882      0.000       0.100       0.200
# C(day_of_week)[T.5]                                                                     1.0490      0.018     57.830      0.000       1.013       1.085
# C(day_of_week)[T.6]                                                                     0.9422      0.018     52.447      0.000       0.907       0.977
# scale(temp)                                                                             0.1842      0.016     11.562      0.000       0.153       0.215
# scale(humidity)                                                                        -0.0533      0.009     -5.620      0.000      -0.072      -0.035
# scale(windspeed)                                                                       -0.0396      0.007     -5.418      0.000      -0.054      -0.025
# scale(np.sin(I(2 * np.pi * (hour / 24))))                                              -0.6790      0.008    -84.712      0.000      -0.695      -0.663
# scale(np.cos(I(2 * np.pi * (hour / 24))))                                              -0.6954      0.007    -93.370      0.000      -0.710      -0.681
# scale(np.sin(I(2 * np.pi * (hour / 24)))):scale(np.cos(I(2 * np.pi * (hour / 24))))    -0.7374      0.009    -78.077      0.000      -0.756      -0.719
# ==============================================================================
# Omnibus:                      120.324   Durbin-Watson:                   0.608
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              124.795
# Skew:                           0.251   Prob(JB):                     7.96e-28
# Kurtosis:                       3.153   Cond. No.                     1.07e+15
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.02e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
train_vif.columns
# Out:
# Index(['holiday', 'workingday', 'weather', 'temp', 'humidity', 'windspeed',
#        'year', 'month', 'hour', 'day', 'day_of_week'],
#       dtype='object')

# %% [markdown]
# 모델에서 여전히 조건수가 높으므로 범주형 변수들의 상관관계를 생각해보면, holiday와 workingday, day_of_week 는 서로 상당히 연관되어 있는 변수들임을 알 수 있다. 따라서 그 세 변수 중 하나만 남기고 나머지는 제거한다. 또한 위에서 확인했듯 일별 자전거 대여수는 별로 차이가 없었기 때문에 day 변수도 삭제한다.

# %%
model4 = sm.OLS.from_formula('np.log1p(count) ~ C(workingday) + C(weather) + scale(temp) + scale(humidity) + \
scale(windspeed) + C(year) + C(month) + C(hour) + 0', train)
result4 = model4.fit()
print(result4.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        np.log1p(count)   R-squared:                       0.833
# Model:                            OLS   Adj. R-squared:                  0.832
# Method:                 Least Squares   F-statistic:                     1285.
# Date:                Wed, 12 Dec 2018   Prob (F-statistic):               0.00
# Time:                        17:27:19   Log-Likelihood:                -9526.8
# No. Observations:               10886   AIC:                         1.914e+04
# Df Residuals:                   10843   BIC:                         1.945e+04
# Df Model:                          42
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# C(workingday)[0]     3.1068      0.041     76.506      0.000       3.027       3.186
# C(workingday)[1]     3.0423      0.040     76.162      0.000       2.964       3.121
# C(weather)[T.2]     -0.0477      0.014     -3.443      0.001      -0.075      -0.021
# C(weather)[T.3]     -0.5118      0.024    -21.625      0.000      -0.558      -0.465
# C(weather)[T.4]     -0.0958      0.583     -0.164      0.869      -1.239       1.047
# C(year)[T.2012]      0.4750      0.011     41.768      0.000       0.453       0.497
# C(month)[T.2]        0.1849      0.028      6.655      0.000       0.130       0.239
# C(month)[T.3]        0.2836      0.029      9.617      0.000       0.226       0.341
# C(month)[T.4]        0.4778      0.031     15.186      0.000       0.416       0.540
# C(month)[T.5]        0.7111      0.036     19.954      0.000       0.641       0.781
# C(month)[T.6]        0.6507      0.041     16.051      0.000       0.571       0.730
# C(month)[T.7]        0.5417      0.046     11.882      0.000       0.452       0.631
# C(month)[T.8]        0.5764      0.044     13.070      0.000       0.490       0.663
# C(month)[T.9]        0.6729      0.039     17.080      0.000       0.596       0.750
# C(month)[T.10]       0.7847      0.034     23.088      0.000       0.718       0.851
# C(month)[T.11]       0.7418      0.029     25.487      0.000       0.685       0.799
# C(month)[T.12]       0.6979      0.029     24.216      0.000       0.641       0.754
# C(hour)[T.1]        -0.6066      0.039    -15.718      0.000      -0.682      -0.531
# C(hour)[T.2]        -1.0991      0.039    -28.369      0.000      -1.175      -1.023
# C(hour)[T.3]        -1.5926      0.039    -40.711      0.000      -1.669      -1.516
# C(hour)[T.4]        -1.8594      0.039    -47.734      0.000      -1.936      -1.783
# C(hour)[T.5]        -0.9009      0.039    -23.243      0.000      -0.977      -0.825
# C(hour)[T.6]         0.2800      0.039      7.233      0.000       0.204       0.356
# C(hour)[T.7]         1.2481      0.039     32.293      0.000       1.172       1.324
# C(hour)[T.8]         1.8753      0.039     48.594      0.000       1.800       1.951
# C(hour)[T.9]         1.5470      0.039     40.049      0.000       1.471       1.623
# C(hour)[T.10]        1.2184      0.039     31.419      0.000       1.142       1.294
# C(hour)[T.11]        1.3348      0.039     34.169      0.000       1.258       1.411
# C(hour)[T.12]        1.5221      0.039     38.634      0.000       1.445       1.599
# C(hour)[T.13]        1.4949      0.040     37.619      0.000       1.417       1.573
# C(hour)[T.14]        1.4106      0.040     35.269      0.000       1.332       1.489
# C(hour)[T.15]        1.4700      0.040     36.677      0.000       1.391       1.549
# C(hour)[T.16]        1.7307      0.040     43.294      0.000       1.652       1.809
# C(hour)[T.17]        2.1429      0.040     53.916      0.000       2.065       2.221
# C(hour)[T.18]        2.0577      0.039     52.131      0.000       1.980       2.135
# C(hour)[T.19]        1.7676      0.039     45.282      0.000       1.691       1.844
# C(hour)[T.20]        1.4693      0.039     37.849      0.000       1.393       1.545
# C(hour)[T.21]        1.2155      0.039     31.435      0.000       1.140       1.291
# C(hour)[T.22]        0.9754      0.039     25.273      0.000       0.900       1.051
# C(hour)[T.23]        0.5807      0.039     15.057      0.000       0.505       0.656
# scale(temp)          0.2104      0.013     15.753      0.000       0.184       0.237
# scale(humidity)     -0.0762      0.008     -9.597      0.000      -0.092      -0.061
# scale(windspeed)    -0.0429      0.006     -6.990      0.000      -0.055      -0.031
# ==============================================================================
# Omnibus:                      806.077   Durbin-Watson:                   0.540
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1521.003
# Skew:                          -0.526   Prob(JB):                         0.00
# Kurtosis:                       4.499   Cond. No.                         122.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# > 이번 모델에서 조건수가 현저히 낮아졌고 성능도 올랐음을 확인할 수 있다.

# %% [markdown]
# 마지막으로 temp와 windspeed에 로그처리를 해 주자 0.01이 더 올랐다.

# %%
model5 = sm.OLS.from_formula('np.log1p(count) ~ C(workingday) + C(weather) + C(hour) + scale(np.log(temp)) \
+ C(month) + scale(humidity) + scale(np.log(windspeed)) + C(year) + 0', train)
result5 = model5.fit()
print(result5.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        np.log1p(count)   R-squared:                       0.834
# Model:                            OLS   Adj. R-squared:                  0.833
# Method:                 Least Squares   F-statistic:                     1294.
# Date:                Wed, 12 Dec 2018   Prob (F-statistic):               0.00
# Time:                        17:49:14   Log-Likelihood:                -9494.3
# No. Observations:               10886   AIC:                         1.907e+04
# Df Residuals:                   10843   BIC:                         1.939e+04
# Df Model:                          42
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# C(workingday)[0]             3.1351      0.040     78.069      0.000       3.056       3.214
# C(workingday)[1]             3.0731      0.040     77.631      0.000       2.995       3.151
# C(weather)[T.2]             -0.0475      0.014     -3.437      0.001      -0.075      -0.020
# C(weather)[T.3]             -0.5111      0.024    -21.647      0.000      -0.557      -0.465
# C(weather)[T.4]             -0.0974      0.581     -0.167      0.867      -1.237       1.042
# C(hour)[T.1]                -0.6053      0.038    -15.730      0.000      -0.681      -0.530
# C(hour)[T.2]                -1.0974      0.039    -28.409      0.000      -1.173      -1.022
# C(hour)[T.3]                -1.5910      0.039    -40.796      0.000      -1.667      -1.515
# C(hour)[T.4]                -1.8583      0.039    -47.854      0.000      -1.934      -1.782
# C(hour)[T.5]                -0.8959      0.039    -23.183      0.000      -0.972      -0.820
# C(hour)[T.6]                 0.2864      0.039      7.419      0.000       0.211       0.362
# C(hour)[T.7]                 1.2587      0.039     32.647      0.000       1.183       1.334
# C(hour)[T.8]                 1.8847      0.038     48.967      0.000       1.809       1.960
# C(hour)[T.9]                 1.5533      0.039     40.339      0.000       1.478       1.629
# C(hour)[T.10]                1.2241      0.039     31.677      0.000       1.148       1.300
# C(hour)[T.11]                1.3382      0.039     34.405      0.000       1.262       1.414
# C(hour)[T.12]                1.5252      0.039     38.925      0.000       1.448       1.602
# C(hour)[T.13]                1.4999      0.039     37.988      0.000       1.422       1.577
# C(hour)[T.14]                1.4168      0.040     35.695      0.000       1.339       1.495
# C(hour)[T.15]                1.4761      0.040     37.122      0.000       1.398       1.554
# C(hour)[T.16]                1.7367      0.040     43.760      0.000       1.659       1.814
# C(hour)[T.17]                2.1477      0.039     54.380      0.000       2.070       2.225
# C(hour)[T.18]                2.0606      0.039     52.481      0.000       1.984       2.138
# C(hour)[T.19]                1.7695      0.039     45.520      0.000       1.693       1.846
# C(hour)[T.20]                1.4699      0.039     37.995      0.000       1.394       1.546
# C(hour)[T.21]                1.2151      0.039     31.525      0.000       1.140       1.291
# C(hour)[T.22]                0.9746      0.038     25.329      0.000       0.899       1.050
# C(hour)[T.23]                0.5798      0.038     15.079      0.000       0.504       0.655
# C(month)[T.2]                0.1480      0.028      5.298      0.000       0.093       0.203
# C(month)[T.3]                0.2212      0.030      7.298      0.000       0.162       0.281
# C(month)[T.4]                0.4083      0.033     12.559      0.000       0.345       0.472
# C(month)[T.5]                0.6648      0.036     18.621      0.000       0.595       0.735
# C(month)[T.6]                0.6401      0.039     16.580      0.000       0.564       0.716
# C(month)[T.7]                0.5739      0.041     13.962      0.000       0.493       0.654
# C(month)[T.8]                0.5976      0.040     14.805      0.000       0.518       0.677
# C(month)[T.9]                0.6546      0.038     17.246      0.000       0.580       0.729
# C(month)[T.10]               0.7239      0.035     20.942      0.000       0.656       0.792
# C(month)[T.11]               0.6692      0.030     22.200      0.000       0.610       0.728
# C(month)[T.12]               0.6363      0.030     21.567      0.000       0.578       0.694
# C(year)[T.2012]              0.4719      0.011     41.621      0.000       0.450       0.494
# scale(np.log(temp))          0.2007      0.011     17.725      0.000       0.178       0.223
# scale(humidity)             -0.0871      0.008    -10.974      0.000      -0.103      -0.072
# scale(np.log(windspeed))    -0.0448      0.006     -7.335      0.000      -0.057      -0.033
# ==============================================================================
# Omnibus:                      817.065   Durbin-Watson:                   0.543
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1580.609
# Skew:                          -0.524   Prob(JB):                         0.00
# Kurtosis:                       4.544   Cond. No.                         122.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### 아웃라이어 처리

# %%
from statsmodels.graphics import utils

# %%
dfX0 = train[['month','temp','weather','humidity','workingday','hour','windspeed','year']]
dfX = sm.add_constant(dfX0)
dfy = pd.DataFrame(train['count'])

# %%
pred = result5.predict(dfX)

influence_count = result5.get_influence()
cooks_d2, pvals = influence_count.cooks_distance
fox_cr = 4 / (len(y) - 2)
idx = np.where(cooks_d2 > fox_cr)[0]

ax = plt.subplot()
plt.scatter(dfy, pred)
plt.scatter(dfy['count'][idx], pred[idx], s=300, c="r", alpha=0.5)
utils.annotate_axes(range(len(idx)), idx,
                    list(zip(dfy['count'][idx], pred[idx])), [(-20, 15)] * len(idx), size="small", ax=ax)
plt.title("bike_sharing 데이터에서 아웃라이어")
plt.show()

# %%
idx2 = list(set(range(len(dfX))).difference(idx))
dfX = dfX.iloc[idx2, :].reset_index(drop=True)
dfy = dfy.iloc[idx2, :].reset_index(drop=True)

# %%
dfX['count'] = dfy

# %%
dfX.tail()
# Out:
#        const  month   temp  weather  humidity  workingday  hour  windspeed  \
# 10226    1.0     12  15.58        1      50.0           1    19    26.0027
# 10227    1.0     12  14.76        1      57.0           1    20    15.0013
# 10228    1.0     12  13.94        1      61.0           1    21    15.0013
# 10229    1.0     12  13.94        1      61.0           1    22     6.0032
# 10230    1.0     12  13.12        1      66.0           1    23     8.9981
#
#        year  count
# 10226  2012    336
# 10227  2012    241
# 10228  2012    168
# 10229  2012    129
# 10230  2012     88

# %%
weather_4 = train[train.weather==4].drop(columns = ['season','holiday','atemp','casual','registered','day','y_m_d',
                                                    'day_of_week'])
weather_4['const'] = 1.0

# %%
weather_4.tail()
# Out:
#       workingday  weather  temp  humidity  windspeed  count  year  month  \
# 5631           1        4   8.2      86.0     6.0032    164  2012      1
#
#       hour  const
# 5631    18    1.0

# %%
dfX = dfX.append(weather_4).reset_index()

# %%
dfX = dfX.drop(columns='index')

# %% [markdown]
# > 아웃라이어 제거 후 변수간 상호작용까지 고려하여 마지막으로 완성된 모델은 다음과 같다.

# %%
model6 = sm.OLS.from_formula('np.log1p(count) ~ C(workingday) + C(weather) + C(hour) / scale(np.log(temp)) \
+ C(month) / scale(humidity) + scale(np.log(windspeed)) + C(year) + 0', dfX)
result6 = model6.fit()
print(result6.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        np.log1p(count)   R-squared:                       0.902
# Model:                            OLS   Adj. R-squared:                  0.901
# Method:                 Least Squares   F-statistic:                     1229.
# Date:                Wed, 12 Dec 2018   Prob (F-statistic):               0.00
# Time:                        18:02:22   Log-Likelihood:                -5930.6
# No. Observations:               10232   AIC:                         1.202e+04
# Df Residuals:                   10155   BIC:                         1.257e+04
# Df Model:                          76
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# C(workingday)[0]                    3.3067      0.032    103.312      0.000       3.244       3.369
# C(workingday)[1]                    3.1800      0.031    101.135      0.000       3.118       3.242
# C(weather)[T.2]                    -0.0517      0.011     -4.812      0.000      -0.073      -0.031
# C(weather)[T.3]                    -0.4910      0.019    -26.135      0.000      -0.528      -0.454
# C(weather)[T.4]                     0.0022      0.438      0.005      0.996      -0.857       0.861
# C(hour)[T.1]                       -0.7081      0.031    -23.117      0.000      -0.768      -0.648
# C(hour)[T.2]                       -1.3190      0.032    -40.764      0.000      -1.382      -1.256
# C(hour)[T.3]                       -1.7328      0.031    -55.456      0.000      -1.794      -1.672
# C(hour)[T.4]                       -1.8736      0.030    -62.375      0.000      -1.932      -1.815
# C(hour)[T.5]                       -0.8342      0.030    -27.477      0.000      -0.894      -0.775
# C(hour)[T.6]                        0.6154      0.032     19.464      0.000       0.553       0.677
# C(hour)[T.7]                        1.6948      0.032     53.109      0.000       1.632       1.757
# C(hour)[T.8]                        2.0957      0.031     67.889      0.000       2.035       2.156
# C(hour)[T.9]                        1.5388      0.029     52.374      0.000       1.481       1.596
# C(hour)[T.10]                       1.2157      0.029     41.370      0.000       1.158       1.273
# C(hour)[T.11]                       1.3327      0.030     44.968      0.000       1.275       1.391
# C(hour)[T.12]                       1.5271      0.030     50.733      0.000       1.468       1.586
# C(hour)[T.13]                       1.5002      0.031     48.930      0.000       1.440       1.560
# C(hour)[T.14]                       1.4081      0.031     45.172      0.000       1.347       1.469
# C(hour)[T.15]                       1.4661      0.031     46.871      0.000       1.405       1.527
# C(hour)[T.16]                       1.7211      0.031     55.266      0.000       1.660       1.782
# C(hour)[T.17]                       2.1318      0.031     69.525      0.000       2.072       2.192
# C(hour)[T.18]                       2.0371      0.030     67.397      0.000       1.978       2.096
# C(hour)[T.19]                       1.7630      0.030     59.363      0.000       1.705       1.821
# C(hour)[T.20]                       1.4631      0.029     49.750      0.000       1.405       1.521
# C(hour)[T.21]                       1.2143      0.029     41.552      0.000       1.157       1.272
# C(hour)[T.22]                       0.9808      0.029     33.581      0.000       0.924       1.038
# C(hour)[T.23]                       0.5872      0.029     20.097      0.000       0.530       0.644
# C(month)[T.2]                       0.1167      0.023      5.102      0.000       0.072       0.161
# C(month)[T.3]                       0.1718      0.025      6.965      0.000       0.123       0.220
# C(month)[T.4]                       0.3115      0.026     11.876      0.000       0.260       0.363
# C(month)[T.5]                       0.5444      0.029     18.755      0.000       0.488       0.601
# C(month)[T.6]                       0.4954      0.031     15.927      0.000       0.434       0.556
# C(month)[T.7]                       0.4424      0.033     13.322      0.000       0.377       0.508
# C(month)[T.8]                       0.4520      0.033     13.875      0.000       0.388       0.516
# C(month)[T.9]                       0.5741      0.031     18.240      0.000       0.512       0.636
# C(month)[T.10]                      0.6346      0.028     22.419      0.000       0.579       0.690
# C(month)[T.11]                      0.5729      0.024     23.771      0.000       0.526       0.620
# C(month)[T.12]                      0.5815      0.024     24.315      0.000       0.535       0.628
# C(year)[T.2012]                     0.4541      0.009     51.132      0.000       0.437       0.471
# C(hour)[0]:scale(np.log(temp))      0.2645      0.022     12.074      0.000       0.222       0.307
# C(hour)[1]:scale(np.log(temp))      0.2568      0.023     11.390      0.000       0.213       0.301
# C(hour)[2]:scale(np.log(temp))      0.2207      0.023      9.450      0.000       0.175       0.266
# C(hour)[3]:scale(np.log(temp))      0.1810      0.023      7.873      0.000       0.136       0.226
# C(hour)[4]:scale(np.log(temp))      0.1899      0.022      8.519      0.000       0.146       0.234
# C(hour)[5]:scale(np.log(temp))      0.2312      0.021     10.977      0.000       0.190       0.272
# C(hour)[6]:scale(np.log(temp))      0.1577      0.023      6.851      0.000       0.113       0.203
# C(hour)[7]:scale(np.log(temp))      0.1719      0.023      7.589      0.000       0.128       0.216
# C(hour)[8]:scale(np.log(temp))      0.1125      0.022      5.119      0.000       0.069       0.156
# C(hour)[9]:scale(np.log(temp))      0.1175      0.021      5.678      0.000       0.077       0.158
# C(hour)[10]:scale(np.log(temp))     0.1747      0.021      8.164      0.000       0.133       0.217
# C(hour)[11]:scale(np.log(temp))     0.2061      0.023      8.995      0.000       0.161       0.251
# C(hour)[12]:scale(np.log(temp))     0.1947      0.024      8.095      0.000       0.148       0.242
# C(hour)[13]:scale(np.log(temp))     0.1991      0.025      7.941      0.000       0.150       0.248
# C(hour)[14]:scale(np.log(temp))     0.2119      0.025      8.317      0.000       0.162       0.262
# C(hour)[15]:scale(np.log(temp))     0.2097      0.026      8.131      0.000       0.159       0.260
# C(hour)[16]:scale(np.log(temp))     0.2508      0.026      9.741      0.000       0.200       0.301
# C(hour)[17]:scale(np.log(temp))     0.2756      0.025     10.974      0.000       0.226       0.325
# C(hour)[18]:scale(np.log(temp))     0.2989      0.025     12.139      0.000       0.251       0.347
# C(hour)[19]:scale(np.log(temp))     0.3030      0.024     12.790      0.000       0.257       0.349
# C(hour)[20]:scale(np.log(temp))     0.3322      0.023     14.160      0.000       0.286       0.378
# C(hour)[21]:scale(np.log(temp))     0.3293      0.023     14.328      0.000       0.284       0.374
# C(hour)[22]:scale(np.log(temp))     0.3292      0.023     14.478      0.000       0.285       0.374
# C(hour)[23]:scale(np.log(temp))     0.3231      0.023     14.293      0.000       0.279       0.367
# C(month)[1]:scale(humidity)        -0.0550      0.018     -3.078      0.002      -0.090      -0.020
# C(month)[2]:scale(humidity)        -0.0137      0.015     -0.919      0.358      -0.043       0.016
# C(month)[3]:scale(humidity)        -0.0688      0.015     -4.573      0.000      -0.098      -0.039
# C(month)[4]:scale(humidity)        -0.1199      0.014     -8.676      0.000      -0.147      -0.093
# C(month)[5]:scale(humidity)        -0.0811      0.015     -5.250      0.000      -0.111      -0.051
# C(month)[6]:scale(humidity)        -0.0628      0.016     -3.844      0.000      -0.095      -0.031
# C(month)[7]:scale(humidity)        -0.0127      0.018     -0.698      0.485      -0.048       0.023
# C(month)[8]:scale(humidity)        -0.0481      0.018     -2.671      0.008      -0.083      -0.013
# C(month)[9]:scale(humidity)        -0.1492      0.019     -7.895      0.000      -0.186      -0.112
# C(month)[10]:scale(humidity)       -0.1386      0.017     -8.244      0.000      -0.172      -0.106
# C(month)[11]:scale(humidity)       -0.1014      0.017     -5.889      0.000      -0.135      -0.068
# C(month)[12]:scale(humidity)       -0.1093      0.016     -6.647      0.000      -0.141      -0.077
# scale(np.log(windspeed))           -0.0386      0.005     -8.084      0.000      -0.048      -0.029
# ==============================================================================
# Omnibus:                      495.821   Durbin-Watson:                   0.762
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              752.976
# Skew:                          -0.433   Prob(JB):                    3.11e-164
# Kurtosis:                       4.007   Cond. No.                         111.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### 교차검증

# %%
from sklearn.model_selection import KFold

# %%
df = dfX

# %%
scores = np.zeros(5)
cv = KFold(5, shuffle=True, random_state=5)
for i, (idx_train, idx_test) in enumerate(cv.split(df)):
    df_train = df.iloc[idx_train]
    df_test = df.iloc[idx_test]
    model = sm.OLS.from_formula('np.log1p(count) ~ C(workingday) + C(weather) + C(hour) / scale(np.log(temp)) \
+ C(month) / scale(humidity) + scale(np.log(windspeed)) + C(year) + 0', df_train)
    result = model.fit()
    
    yhat = np.exp(result.predict(df_test)) -1
    rss = ((df_test['count'] - yhat) ** 2).sum()
    tss = ((df_test['count'] - df_test['count'].mean())** 2).sum()
    rsquared = 1 - rss / tss
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
# Out:
# 학습 R2 = 0.90313394, 검증 R2 = 0.76287341
# 학습 R2 = 0.90061001, 검증 R2 = 0.78351560
# 학습 R2 = 0.90201332, 검증 R2 = 0.77214832
# -----------------------------------------------------------------------
# KeyError                              Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/patsy/categorical.py in categorical_to_int(data, levels, NA_action, origin)
#     345             try:
# --> 346                 out[i] = level_to_int[value]
#     347             except KeyError:
#
# KeyError: 4
#
# During handling of the above exception, another exception occurred:
#
# PatsyError                            Traceback (most recent call last)
# <ipython-input-1010-2ad1e174a65b> in <module>
#       8     result = model.fit()
#       9
# ---> 10     yhat = np.exp(result.predict(df_test)) -1
#      11     rss = ((df_test['count'] - yhat) ** 2).sum()
#      12     tss = ((df_test['count'] - df_test['count'].mean())** 2).sum()
#
# /usr/local/lib/python3.7/site-packages/statsmodels/base/model.py in predict(self, exog, transform, *args, **kwargs)
#     835             orig_exog_len = len(exog)
#     836             is_dict = isinstance(exog, dict)
# --> 837             exog = dmatrix(design_info, exog, return_type="dataframe")
#     838             if orig_exog_len > len(exog) and not is_dict:
#     839                 import warnings
#
# /usr/local/lib/python3.7/site-packages/patsy/highlevel.py in dmatrix(formula_like, data, eval_env, NA_action, return_type)
#     289     eval_env = EvalEnvironment.capture(eval_env, reference=1)
#     290     (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
# --> 291                                       NA_action, return_type)
#     292     if lhs.shape[1] != 0:
#     293         raise PatsyError("encountered outcome variables for a model "
#
# /usr/local/lib/python3.7/site-packages/patsy/highlevel.py in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     167         return build_design_matrices(design_infos, data,
#     168                                      NA_action=NA_action,
# --> 169                                      return_type=return_type)
#     170     else:
#     171         # No builders, but maybe we can still get matrices
#
# /usr/local/lib/python3.7/site-packages/patsy/build.py in build_design_matrices(design_infos, data, NA_action, return_type, dtype)
#     886         for factor_info in six.itervalues(design_info.factor_infos):
#     887             if factor_info not in factor_info_to_values:
# --> 888                 value, is_NA = _eval_factor(factor_info, data, NA_action)
#     889                 factor_info_to_isNAs[factor_info] = is_NA
#     890                 # value may now be a Series, DataFrame, or ndarray
#
# /usr/local/lib/python3.7/site-packages/patsy/build.py in _eval_factor(factor_info, data, NA_action)
#      83         assert factor_info.type == "categorical"
#      84         result = categorical_to_int(result, factor_info.categories, NA_action,
# ---> 85                                     origin=factor_info.factor)
#      86         assert result.ndim == 1
#      87         return result, np.asarray(result == -1)
#
# /usr/local/lib/python3.7/site-packages/patsy/categorical.py in categorical_to_int(data, levels, NA_action, origin)
#     360                                  "observation with value %r does not match "
#     361                                  "any of the expected levels (expected: %s)"
# --> 362                                  % (value, level_str), origin)
#     363             except TypeError:
#     364                 raise PatsyError("Error converting data to categorical: "
#
# PatsyError: Error converting data to categorical: observation with value 4 does not match any of the expected levels (expected: [1, 2, 3])
#     np.log1p(count) ~ C(workingday) + C(weather) + C(hour) / scale(np.log(temp)) + C(month) / scale(humidity) + scale(np.log(windspeed)) + C(year) + 0
#                                       ^^^^^^^^^^

# %% [markdown]
# > weather값이 4인 데이터가 하나밖에 없어서 트레인데이터 내에서 교차검증 시 계속 에러가 나는 것 같다.

# %% [markdown]
# ## 테스트 데이터 전처리

# %%
test = pd.read_csv("test.csv")
test.tail()
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 6488  2012-12-31 19:00:00       1        0           1        2  10.66
# 6489  2012-12-31 20:00:00       1        0           1        2  10.66
# 6490  2012-12-31 21:00:00       1        0           1        1  10.66
# 6491  2012-12-31 22:00:00       1        0           1        1  10.66
# 6492  2012-12-31 23:00:00       1        0           1        1  10.66
#
#        atemp  humidity  windspeed
# 6488  12.880        60    11.0014
# 6489  12.880        60    11.0014
# 6490  12.880        60    11.0014
# 6491  13.635        56     8.9981
# 6492  13.635        65     8.9981

# %%
test.datetime = pd.to_datetime(test.datetime)

# %%
test['year'] = test.datetime.apply(lambda x : x.year)

# %%
test['month'] = test.datetime.apply(lambda x : x.month)

# %%
test['hour'] = test.datetime.apply(lambda x : x.hour)

# %%
test['day'] = test.datetime.apply(lambda x : x.day)

# %%
test['y_m_d'] = test.datetime.apply(lambda x : x.date())

# %%
test['day_of_week'] = test.datetime.apply(lambda x : x.weekday())

# %%
windspeed_mean = test[['windspeed','y_m_d']].groupby(by='y_m_d').agg('mean')
windspeed_mean = windspeed_mean.rename(columns={'windspeed':'windspeed_mean'})

# %%
test = pd.merge(test, windspeed_mean, on='y_m_d')

# %%
new = test.windspeed.values

# %%
for i in range(len(new)):
    if new[i] == 0:
        new[i] = test.windspeed_mean.values[i]

# %%
test.windspeed = new

# %%
test.head()
# Out:
#              datetime  season  holiday  workingday  weather   temp   atemp  \
# 0 2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1 2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2 2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3 2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4 2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed  year  month  hour  day       y_m_d  day_of_week  \
# 0        56  26.002700  2011      1     0   20  2011-01-20            3
# 1        56  13.125579  2011      1     1   20  2011-01-20            3
# 2        56  13.125579  2011      1     2   20  2011-01-20            3
# 3        56  11.001400  2011      1     3   20  2011-01-20            3
# 4        56  11.001400  2011      1     4   20  2011-01-20            3
#
#    windspeed_mean
# 0       13.125579
# 1       13.125579
# 2       13.125579
# 3       13.125579
# 4       13.125579

# %%
test = test.drop(columns=['datetime', 'windspeed_mean'])

# %%
pred = np.exp(result6.predict(test)) -1

# %%
len(pred)
# Out:
# 6493

# %%
submit = pd.read_csv('sampleSubmission.csv')
submit['count'] = pred

# %%
submit.tail()
# Out:
#                  datetime       count
# 6488  2012-12-31 19:00:00  259.428465
# 6489  2012-12-31 20:00:00  185.000069
# 6490  2012-12-31 21:00:00  152.287500
# 6491  2012-12-31 22:00:00  125.116035
# 6492  2012-12-31 23:00:00   80.404417

# %%
submit.to_csv('sampleSubmission.csv', index=False)

# %% [markdown]
# ![image](https://user-images.githubusercontent.com/44221498/49863210-231a7300-fe43-11e8-8134-b3f52cd3acba.png)
